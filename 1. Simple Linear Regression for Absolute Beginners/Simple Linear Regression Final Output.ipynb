# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %%
# In Simple Linear Regression, we predict the value of one variable Y based on another variable X. And we call X, the independent variable and we call
# Y, the dependent variable. In this project I'm going to show you the fundamentals of Simple Linear Regression. I'm going to assume that we own an ice
# cream business and I would like to create a model that could predict the daily revenue in dollars based on the ouside air temperature (degC). We all
# know that when outside air temperature tend to increase, people tend to buy more ice cream, meaning that the revenue tend to increase during
# summertime. The Dataset is composed of:

# Input (X): Outside Air Temperature
# Output (Y): Overall daily revenue generated in dollars

# Here, we only have 2 columns in our data. The first column is the input (X), and that's gonna be the outside air temperature, the independent variable
# and the output variable (Y), daily revenue in dollars which is the dependent variable.

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False) 
# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
sales_df = pd.read_csv('IceCreamData.csv')

# %%
sales_df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
sales_df.head(7)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194
# 5    14.352514  367.940744
# 6    13.707780  308.894518

# %%
sales_df.tail(8)
# Out:
#      Temperature     Revenue
# 492    23.056214  552.819351
# 493    14.931506  377.430928
# 494    25.112066  571.434257
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
sales_df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %% [markdown]
# - **Calculate the average and maximum temperature and revenue using an alternative method**

# %%
sales_df.mean()
# Out:
# Temperature     22.232225
# Revenue        521.570777
# dtype: float64

# %%
sales_df.max()
# Out:
# Temperature      45.0
# Revenue        1000.0
# dtype: float64

# %% [markdown]
# # TASK #3: PERFORM DATA VISUALIZATION

# %%
plt.figure(figsize = (13, 7))
sns.scatterplot(x = 'Temperature', y = 'Revenue', data = sales_df)
plt.grid()

# %%
plt.figure(figsize = (13, 7))
sns.regplot(x = 'Temperature', y = 'Revenue', data = sales_df)
plt.grid()

# %% [markdown]
# # TASK #4: CREATE TESTING AND TRAINING DATASET

# %%
sales_df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
X = sales_df['Temperature']
y = sales_df['Revenue']

# %%
X = np.array(X)
y = np.array(y)

# %%
# reshaping the array from (500,) to (500, 1)
X = X.reshape(-1,1)
print(X.shape)

# reshaping the array from (500,) to (500, 1)
y = y.reshape(-1,1)
print(y.shape)
# Out:
# (500, 1)
# (500, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (400, 1)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
X_test.shape
# Out:
# (100, 1)

# %%
y_test.shape
# Out:
# (100, 1)

# %% [markdown]
# - **Change the split ratio to allocate 30% for testing and 70% for training.**
# - **Confirm that the train test split process is successful.**

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# X_train.shape

# %%
# y_train.shape

# %%
# X_test.shape

# %%
# y_test.shape

# %% [markdown]
# # TASK #5: UNDERSTAND THEORY BEHIND SIMPLE LINER REGRESSION

# %%
# In Simple Linear Regression, we predict the value of one variable Y based on another variable X. X is called the independent variable and Y is called
# the dependent variable. Why is it called simple? Because it examines the relationship between two variables only. Why is it called linear? It is
# because when the independent variable increases (or decreases), the dependent variable increases (or decreases) in a linear fashion.

# The goal is to obtain a relationship (model) between outside air temperature and ice cream sales revenue

# Once the coefficients m and b are obtained, you have obtained a simple linear regression model! The 'trained' model can be later used to predict any
# Revenue (dollars) based on the outside air temperature.

# %% [markdown]
# # TASK #6: TRAIN A SIMPLE LINEAR REGRESSION MODEL IN SCIKIT LEARN

# %%
X_train.shape
# Out:
# (400, 1)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
from sklearn.linear_model import LinearRegression

SimpleLinearRegression = LinearRegression(fit_intercept = True)
SimpleLinearRegression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff(m)', SimpleLinearRegression.coef_)
print('Linear Model Coeff(b)', SimpleLinearRegression.intercept_)
# Out:
# Linear Model Coeff(m) [[21.37706705]]
# Linear Model Coeff(b) [47.5481829]

# %% [markdown]
# - **Set the fit_intercept attribute to False and retrain the model. What do you notice? comment on the result.**

# %%
# SimpleLinearRegression = LinearRegression(fit_intercept = False)
# SimpleLinearRegression.fit(X_train, y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
# print('Linear Model Coeff(m)', SimpleLinearRegression.coef_)
# print('Linear Model Coeff(b)', SimpleLinearRegression.intercept_)
# Out:
# Linear Model Coeff(m) [[23.26190698]]
# Linear Model Coeff(b) 0.0

# %% [markdown]
# # TASK #7: EVALUATE TRAINED SIMPLE LINEAR REGRESSION MODEL IN SCIKIT LEARN

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, SimpleLinearRegression.predict(X_train), color = 'r')
plt.ylabel('Revenue [$]')
plt.xlabel('T [degC]')
plt.title('Revenue Generated vs. Temperature')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature')

# %%
accuracy_LinearRegression = SimpleLinearRegression.score(X_test, y_test)
accuracy_LinearRegression
# Out:
# 0.9820909015975797

# %%
plt.scatter(X_test, y_test, color = 'gray')
plt.plot(X_test, SimpleLinearRegression.predict(X_test), color = 'r')
plt.ylabel('Revenue [$]')
plt.xlabel('T [degC]')
plt.title('Revenue Generated vs. Temperature')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature')

# %%
# Use the trained model to generate predictions

Temp = np.array([20])
Temp = Temp.reshape(-1,1)

Revenue = SimpleLinearRegression.predict(Temp)
print('Revenue Predictions =', Revenue)
# Out:
# Revenue Predictions = [[475.08952399]]

# %% [markdown]
# - **Try at least 3 temperature values and record the output**
# - **Perform a sanity check and comment on your results!**

# %%
newTemp = np.array([35, 23, 40])
newTemp = newTemp.reshape(-1, 1)

Pred = SimpleLinearRegression.predict(newTemp)
print('Revenue Predictions =', Pred)
# Out:
# Revenue Predictions = [[795.74552981]
#  [539.22072516]
#  [902.63086509]]

# %% [markdown]
# # EXCELLENT JOB
